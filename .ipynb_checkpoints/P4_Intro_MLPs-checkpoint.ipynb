# %% [markdown]
# <a href="https://colab.research.google.com/github/dkaratzas/DL2022-23/blob/main/Problems%203%20-%20Intro%20MLPs/P3_Intro_MLP_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%203%20-%20Intro%20MLPs/P3_Intro_MLP.ipynb)

# %% [markdown]
# # Simple MLP in PyTorch
#
# In this notebook we will detail how to create and train a multilayer perceptron using pytorch. We will go through:
#
# 1. Two different ways of creating an MLP
# 2. Create a standard training loop
# 3. Visualize results

# %%
import torch #should be installed by default in any colab notebook
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

plt.rcParams["figure.figsize"] = (20,10)

# %%
# If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

# use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Data
#
# Before training we need data! So lets create an artificial dataset for our model to learn. This is just a setup section, so you can skip it and move on to the model definition if you want.

# %%
#@title The code in this cell defines a function to generate training and validation data, no need to worry about it. Just hit the play button before continuing { display-mode: "form" }
def generate_data(n_samples, generator, regression=False, noise_scale=2, **kwargs):

    if "noise" in kwargs:
        kwargs["noise"] *= noise_scale
    
    x_train, y_train = generator(n_samples, **kwargs) # training data

    x_val, y_val = generator(n_samples, **kwargs) # validation data

    # Plot the data
    fig, ax = plt.subplots(1, 2)
    ax[0].set_title("Training Data") 
    ax[1].set_title("Validation Data")

    if regression:
        ax[0].scatter(x_train, y_train, cmap=plt.cm.coolwarm)
        ax[1].scatter(x_val, y_val, cmap=plt.cm.coolwarm)
    else:
        ax[0].scatter(x_train[:, 0], x_train[:, 1], c=y_train, cmap=plt.cm.coolwarm)
        ax[1].scatter(x_val[:, 0], x_val[:, 1], c=y_val, cmap=plt.cm.coolwarm)

    return x_train, y_train, x_val, y_val

# %%
# !pip install scikit-learn
# find more datasets at https://scikit-learn.org/stable/modules/classes.html#samples-generator
from sklearn.datasets import make_blobs

N = 1000 # number of sample
xBlobsTrain, yBlobsTrain, xBlobsVal, yBlobsVal = generate_data([N, N], make_blobs, centers=[[0, 0.5], [0, -0.5]], cluster_std=0.2)

#Convert the data from numpy arrays into PyTorch tensors
xBlobsTrain = torch.from_numpy(xBlobsTrain).float()
yBlobsTrain = torch.from_numpy(yBlobsTrain).long()
xBlobsVal = torch.from_numpy(xBlobsVal).float()
yBlobsVal = torch.from_numpy(yBlobsVal).long()

# move data to gpu if available
xBlobsTrain = xBlobsTrain.to(device)
yBlobsTrain = yBlobsTrain.to(device)

xBlobsVal = xBlobsVal.to(device)
yBlobsVal = yBlobsVal.to(device)
# Out:
# Requirement already satisfied: scikit-learn in d:\musta\envs\pytorch\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in d:\musta\envs\pytorch\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in d:\musta\envs\pytorch\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\musta\envs\pytorch\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\musta\envs\pytorch\lib\site-packages (from scikit-learn) (3.3.0)

# %%
xBlobsVal.shape
# Out:
# torch.Size([2000, 2])

# %%
#@title The code in this cell is just for visualization no need to worry about it. Just hit the play button before continuing { display-mode: "form" }
# Dont worry about the code in this cell it is just for visualization purposes you dont need to understand or edit it yet

def plot_model(x, y, model, axis):

    mesh = torch.arange(-2, 2, 0.01)

    xx, yy = torch.meshgrid(mesh, mesh)
    with torch.no_grad():
        data = torch.from_numpy(np.vstack((xx.reshape(-1), yy.reshape(-1))).T).float()
        Z = model(data.cuda().detach())
    Z = Z.max(1)[1].reshape(xx.shape)
    axis.contourf(xx, yy, Z.cpu(), cmap=plt.cm.coolwarm, alpha=0.3)
    axis.scatter(x[:, 0].cpu(), x[:, 1].cpu(), c=y.cpu(), s=20, cmap=plt.cm.coolwarm)
    axis.get_xaxis().set_ticks([])
    axis.get_yaxis().set_ticks([])


def plot_regressor(x, y, model, axis):
    
    x_min = torch.min(x.detach())
    x_max = torch.max(x.detach())
    x_range = torch.linspace(x_min, x_max, 100).unsqueeze(1).to(device)
        
    with torch.no_grad():
        y_pred = model(x_range).detach()
        
    axis.scatter(x.cpu(), y.cpu())
    axis.plot(x_range.cpu(), y_pred.cpu(), 'r-', lw=5, label="Model Prediction")
    axis.get_xaxis().set_ticks([])
    axis.get_yaxis().set_ticks([])
    
def draw_plots(x, y, model, losses, visualize_surface = False, visualize_regressor = False):

    if visualize_surface and visualize_regressor:
        raise ValueError("Expected only one of 'visualize_error' or 'visualize_regressor' to be True.")

    if visualize_surface:
        fig, ax = plt.subplots(1, 2)
        ax[0].set_title("Output Space")
        ax[1].set_title("Losses")
        ax[1].plot(losses["train"], label="training loss")
        ax[1].plot(losses["val"], label="validation loss")
        ax[1].set_xlabel("Epoch")
        plot_model(x, y, model, ax[0])
    
    elif visualize_regressor:
        fig, ax = plt.subplots(1, 2)
        ax[0].set_title("Validation Data")
        ax[1].set_title("Losses")
        ax[1].plot(losses["train"], label="training loss")
        ax[1].plot(losses["val"], label="validation loss")
        ax[1].set_xlabel("Epoch")
        plot_regressor(x, y, model, ax[0])

    else:
        plt.plot(losses["train"], label="training loss")
        plt.plot(losses["val"], label="validation loss")
    
    plt.legend()
    plt.pause(0.000001)
    plt.show()

# %% [markdown]
# # The Model

# %% [markdown]
# Now that these basic concepts are out of the way and we have our data lets take a look at how to create a simple MLP in PyTorch
#
# The ```torch.nn``` [package](https://pytorch.org/docs/stable/nn.html) is the one containing all of the neural network related layers, operations etc.
#
# In order to create a simple MLP we can define a sequential module like so:
#
#
#
# ```
# import torch.nn as nn
#
# model = nn.Sequential(nn.Linear(inp_dim, hidden_dim),
#                       nn.ReLU(),
#                       nn.Linear(hidden_dim, output_dim))
# ```
#
# So now we can feed data into this model and the ```nn``` module will take care of the forward pass.
#
# Some more complicated acrchitectures will require you to detail the forward pass of the model. This will require creating a class that inherits from ```nn.Module``` and define its ```forward``` and ```__init__``` methods.
#
# ```
# import torch.nn as nn
#
# class SimpleMLP(nn.Module):
#
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(inp_dim, hidden_dim)
#         self.fc2 = nn.Linear(hidden_dim, output_dim)
#
#
#     def forward(self, x):
#         out = self.fc1(x)
#         out = torch.nn.functional.relu(out)
#         return self.fc2(out)
# ```
#
# Notice how this approach allows more flexibility since we can insert ANY python statement in the forward method, such as ```print```, ```if else```, etc.
#
# Since our model for this first session is very simple we will use the first approach in this notebook, but we encourage you to try your own model using the second approach.

# %% [markdown]
# ## Linear Model

# %% [markdown]
# We will start by defining a very simple, linear model. This is a very inefficient model, but it serves us in order to have a template to build on afterwards.
#
# The input of this model will be set to 2 (we have two features in our datasets) and the output to 2 (we will predict one of two classes).
#
# The output of the model will be a raw, unnormalized score for each class. The scores (the logits) that will then go through softmax plus cross entropy loss to compare against the true labels.

# %%
import torch.nn as nn # nn package to create our linear model

D = 2  # input dimensions
C = 2  # num_classes
H = 100  # num_hidden_units

# each Linear module has a weight and bias
modelMLP = nn.Sequential(
    nn.Linear(D, H),
    nn.Linear(H, C)
)

# move model to gpu if available
modelMLP.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=100, bias=True)
#   (1): Linear(in_features=100, out_features=2, bias=True)
# )

# %%
[p.numel() for p in modelMLP.parameters()]
# Out:
# [200, 100, 200, 2]

# %% [markdown]
# ---
#
# <font color="blue">**Exercise 1**: Redefine the model by implementing a Class that inherits from `nn.Module()` and implementing its `__init__()` and `forward()` methods.</font>

# %%
# Your Code Here
device = 'cuda'
class modelMLP(nn.Module):
    def __init__(self, D, H, C):
        super().__init__()
        self.model = nn.Sequential(
            # input layer
            nn.Linear(D, H),

            # hidden layer
            nn.Linear(H,C),
        )
    def forward(self, x):
        out = self.model(x)
        return out

MLP = modelMLP(2, 100, 2).to(device = device)

# %%
x = torch.tensor([3.0, 7.0]).to(device)
print(x.shape)

MLP(x)
# Out:
# torch.Size([2])
# tensor([-1.6274,  0.3044], device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# ## The Loss

# %% [markdown]
# We will use a criterion (cost) that combines the calculation of softmax and a cross entropy loss in a single block, which is numerically more stable than doing these two steps separately:
#
# https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html

# %%
# we use softmax + cross entropy loss (combined in a single function which unfortunately is called just CrossEntropyLoss) for our classification task

criterion = torch.nn.CrossEntropyLoss() # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss

# %% [markdown]
# The `torch.nn` package has many more loss functions defined. You can check them out here: https://pytorch.org/docs/stable/nn.html#loss-functions

# %% [markdown]
# # Training Loop

# %% [markdown]
# Once we have a model defined, we should set up our training loop

# %%
torch.manual_seed(0) # seed for reproductibility

# %% [markdown]
# ## The optimiser

# %% [markdown]
# The `optimiser` that we define is an object that will take care the update of all the weights in our model. For this, in needs to know where the weights are, and what update rule (optimisation algorithm) to use.
#
# For now we will stick with the "Stochastic Gradient Descent" optimiser. We define this next, setting up also the learning rate, and a few hyperparameters (weight decay and momentum) that we will discuss in more detail in the next lecture.
#
# In reality, this optimiser is just doing standard gradient descent - so here's another misnomer. Whether we will use it in a "stochastic" setting or no, depends on us - on how we will feed in the data during the training loop.

# %%
learning_rate = 1e-3
lambda_l2 = 1e-5

# we use the optim package to apply gradient descent for our parameter updates
optimizer = torch.optim.SGD(MLP.parameters(), lr=learning_rate, momentum=0.9, weight_decay=lambda_l2) # built-in L2

# %% [markdown]
# ## The training loop

# %% [markdown]
# Next we will define our training loop: feedforward, calculate loss, back propagate, and update the weights.
#
# In every step we also keep track of the evolution of our loss, and also the accuracy of our classifier.

# %%
# Training loop
def train(x_train, y_train, x_val, y_val, criterion, model, optimizer, epochs=300, visualize_surface=False):
    
    losses = {"train": [], "val": []} # Two lists to keep track of the evolution of our losses

    for t in range(epochs):
        
        # activate training mode
        model.train()
        
        # Feed forward to get the logits
        y_pred = model(x_train) # x_train is the whole batch, so we are doing full batch gradient descent here
    
        # Compute the loss
        loss = criterion(y_pred.squeeze(), y_train)
        
        # zero the gradients before running the backward pass
        optimizer.zero_grad()
        
        # Backward pass to compute the gradient of loss w.r.t our learnable params
        loss.backward()

        # Update params
        optimizer.step()

        model.eval() # we don't need gradients on to calculate performance, just simple inference
        
        # Compute the accuracy.
        score, predicted = torch.max(y_pred, dim=1) # torch.max() returns the maximum value and the argmax (index of the maximum value)
        train_acc = (y_train == predicted).sum().float() / len(y_train)
        losses["train"].append(loss.item() ) # keep track of our training loss

        # Run model on validation data
        val_loss, val_acc = calculateLossAcc(criterion, model, x_val, y_val) # Call our helper function (see below) on the validation set
        losses["val"].append(val_loss.item()) # keep track of our validation loss

        # Create plots
        display.clear_output(wait=True)
        draw_plots(x_val, y_val, model, losses, visualize_surface, visualize_regressor = False)

        print("Training: [EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (t, loss.item(), train_acc))        
        print("Validation: [EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (t, val_loss.item(), val_acc))
        
    return losses # In case we want to plot them afterwards

# A helper function that calculates our loss and accuracy on a given dataset (by default on our validation set)
def calculateLossAcc(criterion, model, x, y):

    # set model in evaluation mode
    model.eval()
    with torch.no_grad(): # do not compute gradients for validation
        y_pred = model(x)


    # compute loss and accuracy 
    _, predicted = torch.max(y_pred, 1)
    loss = criterion(y_pred.squeeze(), y)
    acc = (y == predicted).sum().float() / len(y)

    return loss, acc

# %% [markdown]
# ## Run Training

# %%
# You can set visualize_surface to False to omit the visualization of the output space. The training will be much faster this way

losses = train(xBlobsTrain, yBlobsTrain, xBlobsVal, yBlobsVal, criterion, MLP, optimizer, visualize_surface=True, epochs = 100)
# Out:
# Training: [EPOCH]: 99, [LOSS]: 0.170826, [ACCURACY]: 0.993
# Validation: [EPOCH]: 99, [LOSS]: 0.170300, [ACCURACY]: 0.994

# %%
# Draw plots once at the end

draw_plots(xBlobsVal, yBlobsVal, MLP, losses, visualize_surface = True)

# %% [markdown]
# ---
#
# <font color="blue">**Exercise 2**: Redefine the model, but now add a non-linear activation function at the hidden layer. Check the `torch.nn.functional` module for possible activation functions to use. </font>

# %%
# Your Code Here
device = 'cuda'
class modelMLP(nn.Module):
    def __init__(self, D, H, C):
        super().__init__()
        self.model = nn.Sequential(
            # input layer
            nn.Linear(D, H),
            # hidden layer
            nn.Linear(H,C),
        )
    def forward(self, x):
        out = self.model(x)
        out = torch.nn.functional.relu(out)
        return out

model = modelMLP(2, 100, 2).to(device = device)

# %%
model
# Out:
# modelMLP(
#   (model): Sequential(
#     (0): Linear(in_features=2, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=2, bias=True)
#   )
# )

# %%
# You can set visualize_surface to False to omit the visualization of the output space. The training will be much faster this way
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=lambda_l2) # built-in L2
losses = train(xBlobsTrain, yBlobsTrain, xBlobsVal, yBlobsVal, criterion, model, optimizer, visualize_surface=True, epochs = 100)
# Out:
# Training: [EPOCH]: 99, [LOSS]: 0.693180, [ACCURACY]: 0.499
# Validation: [EPOCH]: 99, [LOSS]: 0.693155, [ACCURACY]: 0.500

# %% [markdown]
# ## Clean up

# %% [markdown]
# Example code to delete data and clear the cuda cache. Do not run it if you plan to go back to the cells above to try more things.

# %%
del xBlobsTrain, yBlobsTrain, xBlobsVal, yBlobsVal

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %% [markdown]
# # Lets try with a more complex dataset

# %%
def make_spiral(n_points, noise=0.5):

    n = np.sqrt(np.random.rand(n_points, 1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points, 1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points, 1) * noise

    x, y = (np.vstack((np.hstack((d1x, d1y)), np.hstack((-d1x + 1, -d1y)))),
            np.hstack((np.zeros(n_points), np.ones(n_points))).astype("int"))

    x = (x - x.mean()) / x.std()

    return x, y

N = 1000 # number of samples
xSpiralTrain, ySpiralTrain, xSpiralVal, ySpiralVal = generate_data(N, make_spiral, noise=0.5)

#Convert the data from numpy arrays into PyTorch tensors
xSpiralTrain = torch.from_numpy(xSpiralTrain).float()
ySpiralTrain = torch.from_numpy(ySpiralTrain).long()
xSpiralVal = torch.from_numpy(xSpiralVal).float()
ySpiralVal = torch.from_numpy(ySpiralVal).long()

# move data to gpu if available
xSpiralTrain = xSpiralTrain.to(device)
ySpiralTrain = ySpiralTrain.to(device)

xSpiralVal = xSpiralVal.to(device)
ySpiralVal = ySpiralVal.to(device)

# %% [markdown]
# ### Run Training

# %%
# You can set visualize_surface to False to omit the visualization of the output space. The training will be much faster this way

losses = train(xSpiralTrain, ySpiralTrain, xSpiralVal, ySpiralVal, criterion, model, optimizer, visualize_surface=True, epochs = 100)
# Out:
# Training: [EPOCH]: 99, [LOSS]: 0.693147, [ACCURACY]: 0.500
# Validation: [EPOCH]: 99, [LOSS]: 0.693147, [ACCURACY]: 0.500

# %%
# Draw plots once at the end

draw_plots(xSpiralVal, ySpiralVal, model, losses, visualize_surface = True)

# %% [markdown]
# ## Trying more complex models

# %% [markdown]
# As expected, the model we created is too simple to learn anything useful. It can only learn a linear decision boundary.

# %% [markdown]
# <font color="blue">**Exercise 3:** Can you create a model that performs well on this classification task? Change the depth of the model, the number of neurons in different layers, and the activation functions. You might also need to adjust your learning rate and/or the number of epochs.

# %%
# Your Code Here

import torch.nn as nn

class MoreComplexMLP(nn.Module):

    def __init__(self, inDim, outDim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(inDim, 200),
            nn.Linear(200, 100),
            nn.Linear(100, outDim),
        )
        
    def forward(self, x):
        out = self.model(x)
        out = nn.functional.sigmoid(out)
        return out
    
modelComplex = MoreComplexMLP(D, C)

# move model to gpu if available
modelComplex.to(device)

# You can set visualize_surface to False to omit the visualization of the output space. The training will be much faster this way
optimizer = torch.optim.SGD(modelComplex.parameters(), lr=0.005, momentum=0.9, weight_decay=lambda_l2) # built-in L2
# You can set visualize_surface to False to omit the visualization of the output space. The training will be much faster this way
losses = train(xSpiralTrain, ySpiralTrain, xSpiralVal, ySpiralVal, criterion, modelComplex, optimizer, visualize_surface=False, epochs = 150)
# Out:
# Training: [EPOCH]: 149, [LOSS]: 0.656256, [ACCURACY]: 0.600
# Validation: [EPOCH]: 149, [LOSS]: 0.654686, [ACCURACY]: 0.606

# %% [markdown]
# ## Clean up

# %% [markdown]
# Example code to delete data and clear the cuda cache. Do not run it if you plan to go back to the cells above to try more things.

# %%
del xSpiralTrain, ySpiralTrain, xSpiralVal, ySpiralVal
del modelMLP, modelComplex
del criterion
del optimizer

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %% [markdown]
# # Regression

# %% [markdown]
# We can use the same procedure to tackle a regression problem. In this case, we will be producing a continuous output value, and we need to use a different loss.
#
# The code below generates a dataset that can be used for training a regression network

# %%
from sklearn.datasets import make_regression
N = 1000 # number of samples
xRegTrain, yRegTrain, xRegVal, yRegVal = generate_data(N, make_regression, regression=True, noise=5, n_features=1, random_state=52)

#Convert the data from numpy arrays into PyTorch tensors
xRegTrain = torch.from_numpy(xRegTrain).float()
yRegTrain = torch.from_numpy(yRegTrain).float()
xRegVal = torch.from_numpy(xRegVal).float()
yRegVal = torch.from_numpy(yRegVal).float()

# move data to gpu if available
xRegTrain = xRegTrain.to(device)
yRegTrain = yRegTrain.to(device)

xRegVal = xRegVal.to(device)
yRegVal = yRegVal.to(device)
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_24464\4212885377.py:17: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[0].scatter(x_train, y_train, cmap=plt.cm.coolwarm)
# C:\Users\musta\AppData\Local\Temp\ipykernel_24464\4212885377.py:18: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[1].scatter(x_val, y_val, cmap=plt.cm.coolwarm)

# %% [markdown]
# <font color="blue">**Exercise 4:** Using the data generated modify the training code in the cell below to solve a regression problem.</font>
#
#
# > Hints
# >* Note that the generated dataset only has one feature
# >* You can use the same training and validation functions with some slight modifications since it doesn't make sense to calculate accuracy in a regression problem
# >* You can find different training criteria (a.k.a loss functions) in PyTorch [docs](https://pytorch.org/docs/stable/nn.html#loss-functions)

# %%
# Your Code Here
# Training loop
import torch
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np

def train(x_train, y_train, x_val, y_val, criterion, model, optimizer, epochs=300, visualize_surface=False):
    
    losses = {"train": [], "val": []}  # Two lists to keep track of the evolution of our losses

    for t in range(epochs):
        
        # activate training mode
        model.train()
        
        # Feed forward to get the predictions
        y_pred = model(x_train)  # x_train is the whole batch
        
        # Compute the loss
        loss = criterion(y_pred.squeeze(), y_train)
        
        # zero the gradients before running the backward pass
        optimizer.zero_grad()
        
        # Backward pass to compute the gradient of loss w.r.t our learnable params
        loss.backward()

        # Update params
        optimizer.step()

        # Compute the loss on validation set
        model.eval()  
        with torch.no_grad():
            val_loss = criterion(model(x_val).squeeze(), y_val)
        
        # Record the losses
        losses["train"].append(loss.item())
        losses["val"].append(val_loss.item())
        
        # Print loss
        print("Epoch [{}/{}], Training Loss: {:.4f}, Validation Loss: {:.4f}".format(t+1, epochs, loss.item(), val_loss.item()))
        
        # Optionally visualize
        if visualize_surface:
            visualize_regression(x_val, y_val, model)

    return losses

def visualize_regression(x_val, y_val, model):
    model.eval()
    with torch.no_grad():
        y_pred = model(x_val).squeeze().cpu().numpy()
        
        x_val = x_val.cpu().numpy() if isinstance(x_val, torch.Tensor) else x_val
        y_val = y_val.cpu().numpy() if isinstance(y_val, torch.Tensor) else y_val
        
        plt.figure(figsize=(8, 6))
        plt.scatter(x_val, y_val, label='True data')
        plt.scatter(x_val, y_pred, label='Predictions', color='r', alpha=0.5)
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.title('Regression Visualization')
        plt.legend()
        plt.show()
        
class MoreComplexMLP(nn.Module):

    def __init__(self, inDim, outDim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(inDim, 1),
            nn.Linear(1, outDim),
        )
        
    def forward(self, x):
        out = self.model(x)
        return out
    
# Define model, optimizer, criterion
model = MoreComplexMLP(1, 1)  # Assuming 1 output for regression
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Choose device
model = model.to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
criterion = nn.MSELoss()

# Train the model
losses = train(xRegTrain, yRegTrain, xRegVal, yRegVal, criterion, model, optimizer, epochs=15, visualize_surface=True)
# Out:
# Epoch [1/15], Training Loss: 8576.3945, Validation Loss: 8512.7646
# Epoch [2/15], Training Loss: 8512.7646, Validation Loss: 8034.0229
# Epoch [3/15], Training Loss: 8034.0229, Validation Loss: 4873.8608
# Epoch [4/15], Training Loss: 4873.8608, Validation Loss: 1423.5291
# Epoch [5/15], Training Loss: 1423.5291, Validation Loss: 6808.1421
# Epoch [6/15], Training Loss: 6808.1421, Validation Loss: 599.8752
# Epoch [7/15], Training Loss: 599.8752, Validation Loss: 2889.1411
# Epoch [8/15], Training Loss: 2889.1411, Validation Loss: 8530.4346
# Epoch [9/15], Training Loss: 8530.4346, Validation Loss: 8198.1895
# Epoch [10/15], Training Loss: 8198.1895, Validation Loss: 5870.9502
# Epoch [11/15], Training Loss: 5870.9502, Validation Loss: 174.3786
# Epoch [12/15], Training Loss: 174.3786, Validation Loss: 613.6248
# Epoch [13/15], Training Loss: 613.6248, Validation Loss: 2936.5969
# Epoch [14/15], Training Loss: 2936.5969, Validation Loss: 8508.1963
# Epoch [15/15], Training Loss: 8508.1963, Validation Loss: 8028.9482

# %% [markdown]
# ## Clean up

# %% [markdown]
# Example code to delete data and clear the cuda cache. Do not run it if you plan to go back to the cells above to try more things.

# %%
del xRegTrain, yRegTrain, xRegVal, yRegVal
# delete your model, criterion, optimizer

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %% [markdown]
# # More Classes

# %% [markdown]
# In the next cell we will create a dataset with more than 2 classes.

# %%
# find more datasets at https://scikit-learn.org/stable/modules/classes.html#samples-generator
from sklearn.datasets import make_blobs

N = 1000 # number of samples
xManyClassTrain, yManyClassTrain, xManyClassVal, yManyClassVal = generate_data([N, N, N], make_blobs, centers=[[0, 0.5], [0, -0.5], [-0.5, -0.5]], random_state=12, cluster_std=0.2)

#Convert the data from numpy arrays into PyTorch tensors
xManyClassTrain = torch.from_numpy(xManyClassTrain).float()
yManyClassTrain = torch.from_numpy(yManyClassTrain).long()
xManyClassVal = torch.from_numpy(xManyClassVal).float()
yManyClassVal = torch.from_numpy(yManyClassVal).long()

# move data to gpu if available
xManyClassTrain = xManyClassTrain.to(device)
yManyClassTrain = yManyClassTrain.to(device)

xManyClassVal = xManyClassVal.to(device)
yManyClassVal = yManyClassVal.to(device)

# %% [markdown]
# <font color="blue">**Exercise 5:** Using the data generated in the cell above, modify your classification model to tackle a non-binary classification problem.</font>

# %%
def train(x_train, y_train, x_val, y_val, criterion, model, optimizer, epochs=300, visualize_surface=False):
    
    losses = {"train": [], "val": []} # Two lists to keep track of the evolution of our losses

    for t in range(epochs):
        
        # activate training mode
        model.train()
        
        # Feed forward to get the logits
        y_pred = model(x_train) # x_train is the whole batch, so we are doing full batch gradient descent here
    
        # Compute the loss
        loss = criterion(y_pred, y_train)
        
        # zero the gradients before running the backward pass
        optimizer.zero_grad()
        
        # Backward pass to compute the gradient of loss w.r.t our learnable params
        loss.backward()

        # Update params
        optimizer.step()

        model.eval() # we don't need gradients on to calculate performance, just simple inference
        
        # Compute the accuracy.
        _, predicted = torch.max(y_pred, dim=1) # Get the predicted classes
        train_acc = (predicted == y_train).sum().float() / len(y_train)
        losses["train"].append(loss.item() ) # keep track of our training loss

        # Run model on validation data
        val_loss, val_acc = calculateLossAcc(criterion, model, x_val, y_val) # Call our helper function (see below) on the validation set
        losses["val"].append(val_loss.item()) # keep track of our validation loss

        # Optionally, visualize the training process
        if visualize_surface:
            display.clear_output(wait=True)
            draw_plots(x_val, y_val, model, losses, visualize_surface, visualize_regressor=False)

        print("Training: [EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (t, loss.item(), train_acc))        
        print("Validation: [EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (t, val_loss.item(), val_acc))
        
    return losses # In case we want to plot them afterwards

def calculateLossAcc(criterion, model, x, y):

    # Set model in evaluation mode
    model.eval()
    with torch.no_grad(): # Do not compute gradients for validation
        y_pred = model(x)

    # Compute loss and accuracy 
    loss = criterion(y_pred, y)
    _, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)

    return loss, acc

class MoreComplexMLP(nn.Module):
    def __init__(self, inDim, outDim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(inDim, 200),
            nn.Linear(200, 100),
            nn.Linear(100, outDim),  # Modify output dimension to accommodate num_classes
        )
        
    def forward(self, x):
        out = self.model(x)
        out = nn.functional.softmax(out, dim=1)  # Apply softmax to get probabilities
        return out

num_classes = 3 
modelComplex = MoreComplexMLP(inDim=2, outDim=num_classes)

# move model to gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
modelComplex.to(device)

# Define criterion and optimizer
criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for multi-class classification
optimizer = torch.optim.SGD(modelComplex.parameters(), lr=0.005, momentum=0.9)

# Train the model
losses = train(xManyClassTrain, yManyClassTrain, xManyClassVal, yManyClassVal, criterion, modelComplex, optimizer, epochs=150)
# Out:
# Training: [EPOCH]: 0, [LOSS]: 1.086930, [ACCURACY]: 0.475
# Validation: [EPOCH]: 0, [LOSS]: 1.086050, [ACCURACY]: 0.487
# Training: [EPOCH]: 1, [LOSS]: 1.086050, [ACCURACY]: 0.487
# Validation: [EPOCH]: 1, [LOSS]: 1.084380, [ACCURACY]: 0.509
# Training: [EPOCH]: 2, [LOSS]: 1.084380, [ACCURACY]: 0.509
# Validation: [EPOCH]: 2, [LOSS]: 1.082004, [ACCURACY]: 0.538
# Training: [EPOCH]: 3, [LOSS]: 1.082004, [ACCURACY]: 0.538
# Validation: [EPOCH]: 3, [LOSS]: 1.079000, [ACCURACY]: 0.567
# Training: [EPOCH]: 4, [LOSS]: 1.079000, [ACCURACY]: 0.567
# Validation: [EPOCH]: 4, [LOSS]: 1.075440, [ACCURACY]: 0.600
# Training: [EPOCH]: 5, [LOSS]: 1.075440, [ACCURACY]: 0.600
# Validation: [EPOCH]: 5, [LOSS]: 1.071388, [ACCURACY]: 0.622
# Training: [EPOCH]: 6, [LOSS]: 1.071388, [ACCURACY]: 0.622
# Validation: [EPOCH]: 6, [LOSS]: 1.066901, [ACCURACY]: 0.638
# Training: [EPOCH]: 7, [LOSS]: 1.066901, [ACCURACY]: 0.638
# Validation: [EPOCH]: 7, [LOSS]: 1.062034, [ACCURACY]: 0.649
# Training: [EPOCH]: 8, [LOSS]: 1.062034, [ACCURACY]: 0.649
# Validation: [EPOCH]: 8, [LOSS]: 1.056832, [ACCURACY]: 0.653
# Training: [EPOCH]: 9, [LOSS]: 1.056832, [ACCURACY]: 0.653
# Validation: [EPOCH]: 9, [LOSS]: 1.051338, [ACCURACY]: 0.656
# Training: [EPOCH]: 10, [LOSS]: 1.051338, [ACCURACY]: 0.656
# Validation: [EPOCH]: 10, [LOSS]: 1.045588, [ACCURACY]: 0.657
# Training: [EPOCH]: 11, [LOSS]: 1.045588, [ACCURACY]: 0.657
# Validation: [EPOCH]: 11, [LOSS]: 1.039615, [ACCURACY]: 0.659
# Training: [EPOCH]: 12, [LOSS]: 1.039615, [ACCURACY]: 0.659
# Validation: [EPOCH]: 12, [LOSS]: 1.033449, [ACCURACY]: 0.661
# Training: [EPOCH]: 13, [LOSS]: 1.033449, [ACCURACY]: 0.661
# Validation: [EPOCH]: 13, [LOSS]: 1.027114, [ACCURACY]: 0.662
# Training: [EPOCH]: 14, [LOSS]: 1.027114, [ACCURACY]: 0.662
# Validation: [EPOCH]: 14, [LOSS]: 1.020634, [ACCURACY]: 0.666
# Training: [EPOCH]: 15, [LOSS]: 1.020634, [ACCURACY]: 0.666
# Validation: [EPOCH]: 15, [LOSS]: 1.014030, [ACCURACY]: 0.671
# Training: [EPOCH]: 16, [LOSS]: 1.014030, [ACCURACY]: 0.671
# Validation: [EPOCH]: 16, [LOSS]: 1.007322, [ACCURACY]: 0.681
# Training: [EPOCH]: 17, [LOSS]: 1.007322, [ACCURACY]: 0.681
# Validation: [EPOCH]: 17, [LOSS]: 1.000526, [ACCURACY]: 0.696
# Training: [EPOCH]: 18, [LOSS]: 1.000526, [ACCURACY]: 0.696
# Validation: [EPOCH]: 18, [LOSS]: 0.993661, [ACCURACY]: 0.712
# Training: [EPOCH]: 19, [LOSS]: 0.993661, [ACCURACY]: 0.712
# Validation: [EPOCH]: 19, [LOSS]: 0.986743, [ACCURACY]: 0.731
# Training: [EPOCH]: 20, [LOSS]: 0.986743, [ACCURACY]: 0.731
# Validation: [EPOCH]: 20, [LOSS]: 0.979788, [ACCURACY]: 0.747
# Training: [EPOCH]: 21, [LOSS]: 0.979788, [ACCURACY]: 0.747
# Validation: [EPOCH]: 21, [LOSS]: 0.972813, [ACCURACY]: 0.771
# Training: [EPOCH]: 22, [LOSS]: 0.972813, [ACCURACY]: 0.771
# Validation: [EPOCH]: 22, [LOSS]: 0.965833, [ACCURACY]: 0.789
# Training: [EPOCH]: 23, [LOSS]: 0.965833, [ACCURACY]: 0.789
# Validation: [EPOCH]: 23, [LOSS]: 0.958865, [ACCURACY]: 0.804
# Training: [EPOCH]: 24, [LOSS]: 0.958865, [ACCURACY]: 0.804
# Validation: [EPOCH]: 24, [LOSS]: 0.951924, [ACCURACY]: 0.817
# Training: [EPOCH]: 25, [LOSS]: 0.951924, [ACCURACY]: 0.817
# Validation: [EPOCH]: 25, [LOSS]: 0.945025, [ACCURACY]: 0.832
# Training: [EPOCH]: 26, [LOSS]: 0.945025, [ACCURACY]: 0.832
# Validation: [EPOCH]: 26, [LOSS]: 0.938184, [ACCURACY]: 0.845
# Training: [EPOCH]: 27, [LOSS]: 0.938184, [ACCURACY]: 0.845
# Validation: [EPOCH]: 27, [LOSS]: 0.931413, [ACCURACY]: 0.857
# Training: [EPOCH]: 28, [LOSS]: 0.931413, [ACCURACY]: 0.857
# Validation: [EPOCH]: 28, [LOSS]: 0.924727, [ACCURACY]: 0.867
# Training: [EPOCH]: 29, [LOSS]: 0.924727, [ACCURACY]: 0.867
# Validation: [EPOCH]: 29, [LOSS]: 0.918137, [ACCURACY]: 0.875
# Training: [EPOCH]: 30, [LOSS]: 0.918137, [ACCURACY]: 0.875
# Validation: [EPOCH]: 30, [LOSS]: 0.911653, [ACCURACY]: 0.882
# Training: [EPOCH]: 31, [LOSS]: 0.911653, [ACCURACY]: 0.882
# Validation: [EPOCH]: 31, [LOSS]: 0.905286, [ACCURACY]: 0.890
# Training: [EPOCH]: 32, [LOSS]: 0.905286, [ACCURACY]: 0.890
# Validation: [EPOCH]: 32, [LOSS]: 0.899042, [ACCURACY]: 0.893
# Training: [EPOCH]: 33, [LOSS]: 0.899042, [ACCURACY]: 0.893
# Validation: [EPOCH]: 33, [LOSS]: 0.892928, [ACCURACY]: 0.894
# Training: [EPOCH]: 34, [LOSS]: 0.892928, [ACCURACY]: 0.894
# Validation: [EPOCH]: 34, [LOSS]: 0.886948, [ACCURACY]: 0.896
# Training: [EPOCH]: 35, [LOSS]: 0.886948, [ACCURACY]: 0.896
# Validation: [EPOCH]: 35, [LOSS]: 0.881107, [ACCURACY]: 0.897
# Training: [EPOCH]: 36, [LOSS]: 0.881107, [ACCURACY]: 0.897
# Validation: [EPOCH]: 36, [LOSS]: 0.875407, [ACCURACY]: 0.899
# Training: [EPOCH]: 37, [LOSS]: 0.875407, [ACCURACY]: 0.899
# Validation: [EPOCH]: 37, [LOSS]: 0.869847, [ACCURACY]: 0.900
# Training: [EPOCH]: 38, [LOSS]: 0.869847, [ACCURACY]: 0.900
# Validation: [EPOCH]: 38, [LOSS]: 0.864429, [ACCURACY]: 0.903
# Training: [EPOCH]: 39, [LOSS]: 0.864429, [ACCURACY]: 0.903
# Validation: [EPOCH]: 39, [LOSS]: 0.859151, [ACCURACY]: 0.903
# Training: [EPOCH]: 40, [LOSS]: 0.859151, [ACCURACY]: 0.903
# Validation: [EPOCH]: 40, [LOSS]: 0.854012, [ACCURACY]: 0.906
# Training: [EPOCH]: 41, [LOSS]: 0.854012, [ACCURACY]: 0.906
# Validation: [EPOCH]: 41, [LOSS]: 0.849010, [ACCURACY]: 0.908
# Training: [EPOCH]: 42, [LOSS]: 0.849010, [ACCURACY]: 0.908
# Validation: [EPOCH]: 42, [LOSS]: 0.844142, [ACCURACY]: 0.910
# Training: [EPOCH]: 43, [LOSS]: 0.844142, [ACCURACY]: 0.910
# Validation: [EPOCH]: 43, [LOSS]: 0.839405, [ACCURACY]: 0.909
# Training: [EPOCH]: 44, [LOSS]: 0.839405, [ACCURACY]: 0.909
# Validation: [EPOCH]: 44, [LOSS]: 0.834797, [ACCURACY]: 0.910
# Training: [EPOCH]: 45, [LOSS]: 0.834797, [ACCURACY]: 0.910
# Validation: [EPOCH]: 45, [LOSS]: 0.830314, [ACCURACY]: 0.912
# Training: [EPOCH]: 46, [LOSS]: 0.830314, [ACCURACY]: 0.912
# Validation: [EPOCH]: 46, [LOSS]: 0.825952, [ACCURACY]: 0.912
# Training: [EPOCH]: 47, [LOSS]: 0.825952, [ACCURACY]: 0.912
# Validation: [EPOCH]: 47, [LOSS]: 0.821709, [ACCURACY]: 0.913
# Training: [EPOCH]: 48, [LOSS]: 0.821709, [ACCURACY]: 0.913
# Validation: [EPOCH]: 48, [LOSS]: 0.817581, [ACCURACY]: 0.913
# Training: [EPOCH]: 49, [LOSS]: 0.817581, [ACCURACY]: 0.913
# Validation: [EPOCH]: 49, [LOSS]: 0.813565, [ACCURACY]: 0.914
# Training: [EPOCH]: 50, [LOSS]: 0.813565, [ACCURACY]: 0.914
# Validation: [EPOCH]: 50, [LOSS]: 0.809658, [ACCURACY]: 0.914
# Training: [EPOCH]: 51, [LOSS]: 0.809658, [ACCURACY]: 0.914
# Validation: [EPOCH]: 51, [LOSS]: 0.805857, [ACCURACY]: 0.915
# Training: [EPOCH]: 52, [LOSS]: 0.805857, [ACCURACY]: 0.915
# Validation: [EPOCH]: 52, [LOSS]: 0.802158, [ACCURACY]: 0.915
# Training: [EPOCH]: 53, [LOSS]: 0.802158, [ACCURACY]: 0.915
# Validation: [EPOCH]: 53, [LOSS]: 0.798559, [ACCURACY]: 0.916
# Training: [EPOCH]: 54, [LOSS]: 0.798559, [ACCURACY]: 0.916
# Validation: [EPOCH]: 54, [LOSS]: 0.795056, [ACCURACY]: 0.916
# Training: [EPOCH]: 55, [LOSS]: 0.795056, [ACCURACY]: 0.916
# Validation: [EPOCH]: 55, [LOSS]: 0.791647, [ACCURACY]: 0.916
# Training: [EPOCH]: 56, [LOSS]: 0.791647, [ACCURACY]: 0.916
# Validation: [EPOCH]: 56, [LOSS]: 0.788328, [ACCURACY]: 0.916
# Training: [EPOCH]: 57, [LOSS]: 0.788328, [ACCURACY]: 0.916
# Validation: [EPOCH]: 57, [LOSS]: 0.785099, [ACCURACY]: 0.916
# Training: [EPOCH]: 58, [LOSS]: 0.785099, [ACCURACY]: 0.916
# Validation: [EPOCH]: 58, [LOSS]: 0.781954, [ACCURACY]: 0.916
# Training: [EPOCH]: 59, [LOSS]: 0.781954, [ACCURACY]: 0.916
# Validation: [EPOCH]: 59, [LOSS]: 0.778893, [ACCURACY]: 0.916
# Training: [EPOCH]: 60, [LOSS]: 0.778893, [ACCURACY]: 0.916
# Validation: [EPOCH]: 60, [LOSS]: 0.775913, [ACCURACY]: 0.916
# Training: [EPOCH]: 61, [LOSS]: 0.775913, [ACCURACY]: 0.916
# Validation: [EPOCH]: 61, [LOSS]: 0.773010, [ACCURACY]: 0.916
# Training: [EPOCH]: 62, [LOSS]: 0.773010, [ACCURACY]: 0.916
# Validation: [EPOCH]: 62, [LOSS]: 0.770183, [ACCURACY]: 0.917
# Training: [EPOCH]: 63, [LOSS]: 0.770183, [ACCURACY]: 0.917
# Validation: [EPOCH]: 63, [LOSS]: 0.767430, [ACCURACY]: 0.917
# Training: [EPOCH]: 64, [LOSS]: 0.767430, [ACCURACY]: 0.917
# Validation: [EPOCH]: 64, [LOSS]: 0.764749, [ACCURACY]: 0.917
# Training: [EPOCH]: 65, [LOSS]: 0.764749, [ACCURACY]: 0.917
# Validation: [EPOCH]: 65, [LOSS]: 0.762136, [ACCURACY]: 0.917
# Training: [EPOCH]: 66, [LOSS]: 0.762136, [ACCURACY]: 0.917
# Validation: [EPOCH]: 66, [LOSS]: 0.759591, [ACCURACY]: 0.918
# Training: [EPOCH]: 67, [LOSS]: 0.759591, [ACCURACY]: 0.918
# Validation: [EPOCH]: 67, [LOSS]: 0.757112, [ACCURACY]: 0.919
# Training: [EPOCH]: 68, [LOSS]: 0.757112, [ACCURACY]: 0.919
# Validation: [EPOCH]: 68, [LOSS]: 0.754696, [ACCURACY]: 0.919
# Training: [EPOCH]: 69, [LOSS]: 0.754696, [ACCURACY]: 0.919
# Validation: [EPOCH]: 69, [LOSS]: 0.752341, [ACCURACY]: 0.920
# Training: [EPOCH]: 70, [LOSS]: 0.752341, [ACCURACY]: 0.920
# Validation: [EPOCH]: 70, [LOSS]: 0.750047, [ACCURACY]: 0.919
# Training: [EPOCH]: 71, [LOSS]: 0.750047, [ACCURACY]: 0.919
# Validation: [EPOCH]: 71, [LOSS]: 0.747810, [ACCURACY]: 0.920
# Training: [EPOCH]: 72, [LOSS]: 0.747810, [ACCURACY]: 0.920
# Validation: [EPOCH]: 72, [LOSS]: 0.745631, [ACCURACY]: 0.921
# Training: [EPOCH]: 73, [LOSS]: 0.745631, [ACCURACY]: 0.921
# Validation: [EPOCH]: 73, [LOSS]: 0.743506, [ACCURACY]: 0.921
# Training: [EPOCH]: 74, [LOSS]: 0.743506, [ACCURACY]: 0.921
# Validation: [EPOCH]: 74, [LOSS]: 0.741436, [ACCURACY]: 0.921
# Training: [EPOCH]: 75, [LOSS]: 0.741436, [ACCURACY]: 0.921
# Validation: [EPOCH]: 75, [LOSS]: 0.739417, [ACCURACY]: 0.922
# Training: [EPOCH]: 76, [LOSS]: 0.739417, [ACCURACY]: 0.922
# Validation: [EPOCH]: 76, [LOSS]: 0.737450, [ACCURACY]: 0.921
# Training: [EPOCH]: 77, [LOSS]: 0.737450, [ACCURACY]: 0.921
# Validation: [EPOCH]: 77, [LOSS]: 0.735532, [ACCURACY]: 0.921
# Training: [EPOCH]: 78, [LOSS]: 0.735532, [ACCURACY]: 0.921
# Validation: [EPOCH]: 78, [LOSS]: 0.733661, [ACCURACY]: 0.921
# Training: [EPOCH]: 79, [LOSS]: 0.733661, [ACCURACY]: 0.921
# Validation: [EPOCH]: 79, [LOSS]: 0.731838, [ACCURACY]: 0.921
# Training: [EPOCH]: 80, [LOSS]: 0.731838, [ACCURACY]: 0.921
# Validation: [EPOCH]: 80, [LOSS]: 0.730061, [ACCURACY]: 0.922
# Training: [EPOCH]: 81, [LOSS]: 0.730061, [ACCURACY]: 0.922
# Validation: [EPOCH]: 81, [LOSS]: 0.728327, [ACCURACY]: 0.923
# Training: [EPOCH]: 82, [LOSS]: 0.728327, [ACCURACY]: 0.923
# Validation: [EPOCH]: 82, [LOSS]: 0.726637, [ACCURACY]: 0.923
# Training: [EPOCH]: 83, [LOSS]: 0.726637, [ACCURACY]: 0.923
# Validation: [EPOCH]: 83, [LOSS]: 0.724989, [ACCURACY]: 0.922
# Training: [EPOCH]: 84, [LOSS]: 0.724989, [ACCURACY]: 0.922
# Validation: [EPOCH]: 84, [LOSS]: 0.723382, [ACCURACY]: 0.922
# Training: [EPOCH]: 85, [LOSS]: 0.723382, [ACCURACY]: 0.922
# Validation: [EPOCH]: 85, [LOSS]: 0.721814, [ACCURACY]: 0.922
# Training: [EPOCH]: 86, [LOSS]: 0.721814, [ACCURACY]: 0.922
# Validation: [EPOCH]: 86, [LOSS]: 0.720285, [ACCURACY]: 0.922
# Training: [EPOCH]: 87, [LOSS]: 0.720285, [ACCURACY]: 0.922
# Validation: [EPOCH]: 87, [LOSS]: 0.718795, [ACCURACY]: 0.922
# Training: [EPOCH]: 88, [LOSS]: 0.718795, [ACCURACY]: 0.922
# Validation: [EPOCH]: 88, [LOSS]: 0.717340, [ACCURACY]: 0.922
# Training: [EPOCH]: 89, [LOSS]: 0.717340, [ACCURACY]: 0.922
# Validation: [EPOCH]: 89, [LOSS]: 0.715922, [ACCURACY]: 0.922
# Training: [EPOCH]: 90, [LOSS]: 0.715922, [ACCURACY]: 0.922
# Validation: [EPOCH]: 90, [LOSS]: 0.714538, [ACCURACY]: 0.921
# Training: [EPOCH]: 91, [LOSS]: 0.714538, [ACCURACY]: 0.921
# Validation: [EPOCH]: 91, [LOSS]: 0.713188, [ACCURACY]: 0.921
# Training: [EPOCH]: 92, [LOSS]: 0.713188, [ACCURACY]: 0.921
# Validation: [EPOCH]: 92, [LOSS]: 0.711871, [ACCURACY]: 0.921
# Training: [EPOCH]: 93, [LOSS]: 0.711871, [ACCURACY]: 0.921
# Validation: [EPOCH]: 93, [LOSS]: 0.710586, [ACCURACY]: 0.921
# Training: [EPOCH]: 94, [LOSS]: 0.710586, [ACCURACY]: 0.921
# Validation: [EPOCH]: 94, [LOSS]: 0.709332, [ACCURACY]: 0.921
# Training: [EPOCH]: 95, [LOSS]: 0.709332, [ACCURACY]: 0.921
# Validation: [EPOCH]: 95, [LOSS]: 0.708108, [ACCURACY]: 0.921
# Training: [EPOCH]: 96, [LOSS]: 0.708108, [ACCURACY]: 0.921
# Validation: [EPOCH]: 96, [LOSS]: 0.706914, [ACCURACY]: 0.922
# Training: [EPOCH]: 97, [LOSS]: 0.706914, [ACCURACY]: 0.922
# Validation: [EPOCH]: 97, [LOSS]: 0.705749, [ACCURACY]: 0.921
# Training: [EPOCH]: 98, [LOSS]: 0.705749, [ACCURACY]: 0.921
# Validation: [EPOCH]: 98, [LOSS]: 0.704611, [ACCURACY]: 0.921
# Training: [EPOCH]: 99, [LOSS]: 0.704611, [ACCURACY]: 0.921
# Validation: [EPOCH]: 99, [LOSS]: 0.703501, [ACCURACY]: 0.921
# Training: [EPOCH]: 100, [LOSS]: 0.703501, [ACCURACY]: 0.921
# Validation: [EPOCH]: 100, [LOSS]: 0.702416, [ACCURACY]: 0.921
# Training: [EPOCH]: 101, [LOSS]: 0.702416, [ACCURACY]: 0.921
# Validation: [EPOCH]: 101, [LOSS]: 0.701358, [ACCURACY]: 0.921
# Training: [EPOCH]: 102, [LOSS]: 0.701358, [ACCURACY]: 0.921
# Validation: [EPOCH]: 102, [LOSS]: 0.700324, [ACCURACY]: 0.921
# Training: [EPOCH]: 103, [LOSS]: 0.700324, [ACCURACY]: 0.921
# Validation: [EPOCH]: 103, [LOSS]: 0.699315, [ACCURACY]: 0.921
# Training: [EPOCH]: 104, [LOSS]: 0.699315, [ACCURACY]: 0.921
# Validation: [EPOCH]: 104, [LOSS]: 0.698329, [ACCURACY]: 0.921
# Training: [EPOCH]: 105, [LOSS]: 0.698329, [ACCURACY]: 0.921
# Validation: [EPOCH]: 105, [LOSS]: 0.697366, [ACCURACY]: 0.921
# Training: [EPOCH]: 106, [LOSS]: 0.697366, [ACCURACY]: 0.921
# Validation: [EPOCH]: 106, [LOSS]: 0.696425, [ACCURACY]: 0.921
# Training: [EPOCH]: 107, [LOSS]: 0.696425, [ACCURACY]: 0.921
# Validation: [EPOCH]: 107, [LOSS]: 0.695506, [ACCURACY]: 0.921
# Training: [EPOCH]: 108, [LOSS]: 0.695506, [ACCURACY]: 0.921
# Validation: [EPOCH]: 108, [LOSS]: 0.694608, [ACCURACY]: 0.922
# Training: [EPOCH]: 109, [LOSS]: 0.694608, [ACCURACY]: 0.922
# Validation: [EPOCH]: 109, [LOSS]: 0.693731, [ACCURACY]: 0.922
# Training: [EPOCH]: 110, [LOSS]: 0.693731, [ACCURACY]: 0.922
# Validation: [EPOCH]: 110, [LOSS]: 0.692873, [ACCURACY]: 0.922
# Training: [EPOCH]: 111, [LOSS]: 0.692873, [ACCURACY]: 0.922
# Validation: [EPOCH]: 111, [LOSS]: 0.692034, [ACCURACY]: 0.922
# Training: [EPOCH]: 112, [LOSS]: 0.692034, [ACCURACY]: 0.922
# Validation: [EPOCH]: 112, [LOSS]: 0.691215, [ACCURACY]: 0.922
# Training: [EPOCH]: 113, [LOSS]: 0.691215, [ACCURACY]: 0.922
# Validation: [EPOCH]: 113, [LOSS]: 0.690414, [ACCURACY]: 0.921
# Training: [EPOCH]: 114, [LOSS]: 0.690414, [ACCURACY]: 0.921
# Validation: [EPOCH]: 114, [LOSS]: 0.689630, [ACCURACY]: 0.921
# Training: [EPOCH]: 115, [LOSS]: 0.689630, [ACCURACY]: 0.921
# Validation: [EPOCH]: 115, [LOSS]: 0.688863, [ACCURACY]: 0.921
# Training: [EPOCH]: 116, [LOSS]: 0.688863, [ACCURACY]: 0.921
# Validation: [EPOCH]: 116, [LOSS]: 0.688114, [ACCURACY]: 0.921
# Training: [EPOCH]: 117, [LOSS]: 0.688114, [ACCURACY]: 0.921
# Validation: [EPOCH]: 117, [LOSS]: 0.687380, [ACCURACY]: 0.922
# Training: [EPOCH]: 118, [LOSS]: 0.687380, [ACCURACY]: 0.922
# Validation: [EPOCH]: 118, [LOSS]: 0.686662, [ACCURACY]: 0.922
# Training: [EPOCH]: 119, [LOSS]: 0.686662, [ACCURACY]: 0.922
# Validation: [EPOCH]: 119, [LOSS]: 0.685960, [ACCURACY]: 0.922
# Training: [EPOCH]: 120, [LOSS]: 0.685960, [ACCURACY]: 0.922
# Validation: [EPOCH]: 120, [LOSS]: 0.685273, [ACCURACY]: 0.922
# Training: [EPOCH]: 121, [LOSS]: 0.685273, [ACCURACY]: 0.922
# Validation: [EPOCH]: 121, [LOSS]: 0.684600, [ACCURACY]: 0.922
# Training: [EPOCH]: 122, [LOSS]: 0.684600, [ACCURACY]: 0.922
# Validation: [EPOCH]: 122, [LOSS]: 0.683942, [ACCURACY]: 0.922
# Training: [EPOCH]: 123, [LOSS]: 0.683942, [ACCURACY]: 0.922
# Validation: [EPOCH]: 123, [LOSS]: 0.683297, [ACCURACY]: 0.922
# Training: [EPOCH]: 124, [LOSS]: 0.683297, [ACCURACY]: 0.922
# Validation: [EPOCH]: 124, [LOSS]: 0.682665, [ACCURACY]: 0.922
# Training: [EPOCH]: 125, [LOSS]: 0.682665, [ACCURACY]: 0.922
# Validation: [EPOCH]: 125, [LOSS]: 0.682047, [ACCURACY]: 0.922
# Training: [EPOCH]: 126, [LOSS]: 0.682047, [ACCURACY]: 0.922
# Validation: [EPOCH]: 126, [LOSS]: 0.681441, [ACCURACY]: 0.922
# Training: [EPOCH]: 127, [LOSS]: 0.681441, [ACCURACY]: 0.922
# Validation: [EPOCH]: 127, [LOSS]: 0.680847, [ACCURACY]: 0.922
# Training: [EPOCH]: 128, [LOSS]: 0.680847, [ACCURACY]: 0.922
# Validation: [EPOCH]: 128, [LOSS]: 0.680266, [ACCURACY]: 0.922
# Training: [EPOCH]: 129, [LOSS]: 0.680266, [ACCURACY]: 0.922
# Validation: [EPOCH]: 129, [LOSS]: 0.679696, [ACCURACY]: 0.922
# Training: [EPOCH]: 130, [LOSS]: 0.679696, [ACCURACY]: 0.922
# Validation: [EPOCH]: 130, [LOSS]: 0.679138, [ACCURACY]: 0.922
# Training: [EPOCH]: 131, [LOSS]: 0.679138, [ACCURACY]: 0.922
# Validation: [EPOCH]: 131, [LOSS]: 0.678590, [ACCURACY]: 0.922
# Training: [EPOCH]: 132, [LOSS]: 0.678590, [ACCURACY]: 0.922
# Validation: [EPOCH]: 132, [LOSS]: 0.678053, [ACCURACY]: 0.922
# Training: [EPOCH]: 133, [LOSS]: 0.678053, [ACCURACY]: 0.922
# Validation: [EPOCH]: 133, [LOSS]: 0.677527, [ACCURACY]: 0.922
# Training: [EPOCH]: 134, [LOSS]: 0.677527, [ACCURACY]: 0.922
# Validation: [EPOCH]: 134, [LOSS]: 0.677011, [ACCURACY]: 0.922
# Training: [EPOCH]: 135, [LOSS]: 0.677011, [ACCURACY]: 0.922
# Validation: [EPOCH]: 135, [LOSS]: 0.676504, [ACCURACY]: 0.922
# Training: [EPOCH]: 136, [LOSS]: 0.676504, [ACCURACY]: 0.922
# Validation: [EPOCH]: 136, [LOSS]: 0.676008, [ACCURACY]: 0.921
# Training: [EPOCH]: 137, [LOSS]: 0.676008, [ACCURACY]: 0.921
# Validation: [EPOCH]: 137, [LOSS]: 0.675521, [ACCURACY]: 0.921
# Training: [EPOCH]: 138, [LOSS]: 0.675521, [ACCURACY]: 0.921
# Validation: [EPOCH]: 138, [LOSS]: 0.675043, [ACCURACY]: 0.921
# Training: [EPOCH]: 139, [LOSS]: 0.675043, [ACCURACY]: 0.921
# Validation: [EPOCH]: 139, [LOSS]: 0.674573, [ACCURACY]: 0.921
# Training: [EPOCH]: 140, [LOSS]: 0.674573, [ACCURACY]: 0.921
# Validation: [EPOCH]: 140, [LOSS]: 0.674113, [ACCURACY]: 0.921
# Training: [EPOCH]: 141, [LOSS]: 0.674113, [ACCURACY]: 0.921
# Validation: [EPOCH]: 141, [LOSS]: 0.673661, [ACCURACY]: 0.921
# Training: [EPOCH]: 142, [LOSS]: 0.673661, [ACCURACY]: 0.921
# Validation: [EPOCH]: 142, [LOSS]: 0.673217, [ACCURACY]: 0.921
# Training: [EPOCH]: 143, [LOSS]: 0.673217, [ACCURACY]: 0.921
# Validation: [EPOCH]: 143, [LOSS]: 0.672781, [ACCURACY]: 0.922
# Training: [EPOCH]: 144, [LOSS]: 0.672781, [ACCURACY]: 0.922
# Validation: [EPOCH]: 144, [LOSS]: 0.672353, [ACCURACY]: 0.922
# Training: [EPOCH]: 145, [LOSS]: 0.672353, [ACCURACY]: 0.922
# Validation: [EPOCH]: 145, [LOSS]: 0.671933, [ACCURACY]: 0.922
# Training: [EPOCH]: 146, [LOSS]: 0.671933, [ACCURACY]: 0.922
# Validation: [EPOCH]: 146, [LOSS]: 0.671520, [ACCURACY]: 0.922
# Training: [EPOCH]: 147, [LOSS]: 0.671520, [ACCURACY]: 0.922
# Validation: [EPOCH]: 147, [LOSS]: 0.671115, [ACCURACY]: 0.922
# Training: [EPOCH]: 148, [LOSS]: 0.671115, [ACCURACY]: 0.922
# Validation: [EPOCH]: 148, [LOSS]: 0.670716, [ACCURACY]: 0.922
# Training: [EPOCH]: 149, [LOSS]: 0.670716, [ACCURACY]: 0.922
# Validation: [EPOCH]: 149, [LOSS]: 0.670324, [ACCURACY]: 0.922

# %%
del xManyClassTrain, yManyClassTrain, xManyClassVal, yManyClassVal
# delete your model, criterion, optimizer

torch.cuda.empty_cache()
torch.cuda.ipc_collect()
